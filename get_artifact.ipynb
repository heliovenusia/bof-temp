# %%
from __future__ import print_function
import os, json, numpy as np, pandas as pd, tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

pd.options.display.float_format = '{:.3f}'.format

train_candidates = [
    "/mnt/data/bof_train.csv",
    "/content/bof_train.csv",
    "bof_train.csv",
    "https://raw.githubusercontent.com/nichepah/ml-colab/master/bof_train.csv",
]
test_candidates = [
    "/mnt/data/bof_test.csv",
    "/content/bof_test.csv",
    "bof_test.csv",
    "https://raw.githubusercontent.com/nichepah/ml-colab/master/bof_test.csv",
]

FEATURES = ["scrap","silicon","Mn","C","S","P","hot_metal_weight","blow_duration","lime","iron_ore","dolo","sinter","O2","basicity","FeO"]

def _read_first_ok(cands):
    last_e = None
    for p in cands:
        try:
            return pd.read_csv(p, sep=",")
        except Exception as e:
            last_e = e
    raise RuntimeError(str(last_e))

def _force_numeric(df):
    for c in FEATURES + (["temp"] if "temp" in df.columns else []):
        if c in df.columns:
            df[c] = pd.to_numeric(df[c], errors="coerce")
    return df

bof_temp_dataframe = _read_first_ok(train_candidates)
bof_temp_dataframe = _force_numeric(bof_temp_dataframe)
bof_temp_dataframe = bof_temp_dataframe.dropna(subset=["hot_metal_weight","temp"])
bof_temp_dataframe = bof_temp_dataframe.dropna(subset=FEATURES)
bof_temp_dataframe = bof_temp_dataframe[bof_temp_dataframe.hot_metal_weight > 90]
bof_temp_dataframe = bof_temp_dataframe[bof_temp_dataframe.temp > 1200]
bof_temp_dataframe = bof_temp_dataframe[(bof_temp_dataframe.blow_duration > 10) & (bof_temp_dataframe.blow_duration < 50)]
bof_temp_dataframe = bof_temp_dataframe.reindex(np.random.permutation(bof_temp_dataframe.index)).reset_index(drop=True)

def preprocess_features(df):
    x = df[FEATURES].copy()
    x["hot_metal_weight"] = df["hot_metal_weight"] * 1000.0
    return x

def preprocess_targets(df):
    return df[["temp"]].copy()

training_examples = preprocess_features(bof_temp_dataframe.head(1000))
training_targets = preprocess_targets(bof_temp_dataframe.head(1000))
validation_examples = preprocess_features(bof_temp_dataframe.tail(320))
validation_targets = preprocess_targets(bof_temp_dataframe.tail(320))

X_train = training_examples.values.astype(np.float32)
y_train = training_targets["temp"].values.astype(np.float32)
X_val = validation_examples.values.astype(np.float32)
y_val = validation_targets["temp"].values.astype(np.float32)

mu = X_train.mean(axis=0)
sigma = X_train.std(axis=0)
sigma = np.where(sigma < 1e-6, 1.0, sigma)

X_train_s = (X_train - mu) / sigma
X_val_s = (X_val - mu) / sigma

model = keras.Sequential([
    layers.Input(shape=(15,)),
    layers.Dense(15, activation="relu"),
    layers.Dense(10, activation="relu"),
    layers.Dense(5, activation="relu"),
    layers.Dense(1)
])

opt = keras.optimizers.SGD(learning_rate=0.01, clipnorm=5.0)
model.compile(optimizer=opt, loss="mse", metrics=[keras.metrics.RootMeanSquaredError()])
model.fit(X_train_s, y_train, validation_data=(X_val_s, y_val), epochs=200, batch_size=20, verbose=1)

bof_temp_test_data = _read_first_ok(test_candidates)
bof_temp_test_data = _force_numeric(bof_temp_test_data)
bof_temp_test_data = bof_temp_test_data.dropna(subset=FEATURES)

test_examples = preprocess_features(bof_temp_test_data)
X_test = test_examples.values.astype(np.float32)
X_test_s = (X_test - mu) / sigma
pred = model.predict(X_test_s, verbose=0).reshape(-1)

out_df = bof_temp_test_data.copy()
out_df["p_temp"] = pred

rmse = None
if "temp" in out_df.columns:
    y_true = pd.to_numeric(out_df["temp"], errors="coerce").values.astype(np.float32)
    m = np.isfinite(y_true) & np.isfinite(pred)
    if m.any():
        rmse = float(np.sqrt(np.mean((pred[m] - y_true[m])**2)))

UNITS = {"scrap":"tonne","silicon":"%","Mn":"%","C":"%","S":"%","P":"%","hot_metal_weight":"tonne","blow_duration":"min","lime":"kg","iron_ore":"kg","dolo":"kg","sinter":"kg","O2":"Nm3","basicity":"ratio","FeO":"%"}
ranges = {}
df_clean_ui = bof_temp_dataframe.copy()
for f in FEATURES:
    ranges[f] = {"min": float(df_clean_ui[f].min()), "max": float(df_clean_ui[f].max())}

os.makedirs("artifacts", exist_ok=True)
model.save("artifacts/bof_temp_model.keras")
out_df.to_csv("artifacts/pred.csv", index=False)

schema = {
  "features_ordered": FEATURES,
  "units": UNITS,
  "ranges": ranges,
  "transforms": {
      "hot_metal_weight": "UI in tonne; internally multiplied by 1000 (tonne→kg)",
      "standardization": "Inputs standardized using training mean/std (z-score) for stable inference"
  },
  "standardization_params": {
      "mean": [float(x) for x in mu.tolist()],
      "std": [float(x) for x in sigma.tolist()]
  },
  "target": {"name":"temp","unit":"C"},
  "training": {
      "tf_version": tf.__version__,
      "rows_cleaned": int(len(bof_temp_dataframe)),
      "train_rows": int(len(training_examples)),
      "val_rows": int(len(validation_examples)),
      "val_rmse_last_epoch": float(model.evaluate(X_val_s, y_val, verbose=0)[1])
  }
}

with open("artifacts/feature_schema.json","w") as fp:
    json.dump(schema, fp, indent=2)

print("TF", tf.__version__)
print("X_train", X_train.shape, "y_train", y_train.shape)
print("X_val", X_val.shape, "y_val", y_val.shape)
print("pred[:5]", pred[:5])
print("test_rmse", rmse)
print("saved:", "artifacts/bof_temp_model.keras", "artifacts/feature_schema.json", "artifacts/pred.csv")
# Out:
# Epoch 1/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 2688099.7500 - root_mean_squared_error: 1639.4983 - val_loss: 2216762.7500 - val_root_mean_squared_error: 1488.8796
# Epoch 2/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1776857.2500 - root_mean_squared_error: 1328.1040 - val_loss: 250649.7031 - val_root_mean_squared_error: 500.6493
# Epoch 3/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 90629.6875 - root_mean_squared_error: 297.6214 - val_loss: 179610.1250 - val_root_mean_squared_error: 423.8044
# Epoch 4/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 18806.5000 - root_mean_squared_error: 135.1736 - val_loss: 99005.7266 - val_root_mean_squared_error: 314.6518
# Epoch 5/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11027.3242 - root_mean_squared_error: 104.6598 - val_loss: 77001.0156 - val_root_mean_squared_error: 277.4906
# Epoch 6/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6403.6177 - root_mean_squared_error: 79.7287 - val_loss: 72224.1953 - val_root_mean_squared_error: 268.7456
# Epoch 7/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5531.4077 - root_mean_squared_error: 74.1231 - val_loss: 55940.7109 - val_root_mean_squared_error: 236.5179
# Epoch 8/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4155.0308 - root_mean_squared_error: 64.1359 - val_loss: 47555.2891 - val_root_mean_squared_error: 218.0717
# Epoch 9/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3892.7815 - root_mean_squared_error: 62.2024 - val_loss: 39216.3320 - val_root_mean_squared_error: 198.0311
# Epoch 10/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3760.3579 - root_mean_squared_error: 61.2583 - val_loss: 40138.8203 - val_root_mean_squared_error: 200.3468
# Epoch 11/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3090.4580 - root_mean_squared_error: 55.5655 - val_loss: 34384.0586 - val_root_mean_squared_error: 185.4294
# Epoch 12/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2491.6455 - root_mean_squared_error: 49.8321 - val_loss: 31206.2441 - val_root_mean_squared_error: 176.6529
# Epoch 13/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2525.0090 - root_mean_squared_error: 50.1352 - val_loss: 32310.7090 - val_root_mean_squared_error: 179.7518
# Epoch 14/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2364.7676 - root_mean_squared_error: 48.6057 - val_loss: 29186.8496 - val_root_mean_squared_error: 170.8416
# Epoch 15/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2997.9749 - root_mean_squared_error: 54.4680 - val_loss: 26914.4473 - val_root_mean_squared_error: 164.0562
# Epoch 16/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2965.1016 - root_mean_squared_error: 54.3939 - val_loss: 28042.7129 - val_root_mean_squared_error: 167.4596
# Epoch 17/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3055.4612 - root_mean_squared_error: 55.0990 - val_loss: 24324.2520 - val_root_mean_squared_error: 155.9623
# Epoch 18/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2622.6133 - root_mean_squared_error: 51.1977 - val_loss: 25692.0527 - val_root_mean_squared_error: 160.2874
# Epoch 19/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2673.2495 - root_mean_squared_error: 51.6524 - val_loss: 24467.1328 - val_root_mean_squared_error: 156.4197
# Epoch 20/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2505.7329 - root_mean_squared_error: 50.0245 - val_loss: 25657.3145 - val_root_mean_squared_error: 160.1790
# Epoch 21/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2435.9790 - root_mean_squared_error: 49.2938 - val_loss: 24724.8066 - val_root_mean_squared_error: 157.2412
# Epoch 22/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2459.2664 - root_mean_squared_error: 49.5138 - val_loss: 24010.0977 - val_root_mean_squared_error: 154.9519
# Epoch 23/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2561.0464 - root_mean_squared_error: 50.5967 - val_loss: 24143.9590 - val_root_mean_squared_error: 155.3833
# Epoch 24/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2429.2656 - root_mean_squared_error: 49.2526 - val_loss: 24172.8906 - val_root_mean_squared_error: 155.4763
# Epoch 25/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2489.8860 - root_mean_squared_error: 49.8119 - val_loss: 23723.3281 - val_root_mean_squared_error: 154.0238
# Epoch 26/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2308.4194 - root_mean_squared_error: 48.0041 - val_loss: 21365.7676 - val_root_mean_squared_error: 146.1703
# Epoch 27/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2910.2593 - root_mean_squared_error: 53.5144 - val_loss: 23084.0898 - val_root_mean_squared_error: 151.9345
# Epoch 28/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2349.1084 - root_mean_squared_error: 48.4221 - val_loss: 22062.5273 - val_root_mean_squared_error: 148.5346
# Epoch 29/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2450.0439 - root_mean_squared_error: 49.4737 - val_loss: 22394.3945 - val_root_mean_squared_error: 149.6476
# Epoch 30/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2365.9155 - root_mean_squared_error: 48.6053 - val_loss: 22786.3340 - val_root_mean_squared_error: 150.9514
# Epoch 31/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2651.0886 - root_mean_squared_error: 51.3933 - val_loss: 22985.2012 - val_root_mean_squared_error: 151.6087
# Epoch 32/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2287.7644 - root_mean_squared_error: 47.7834 - val_loss: 21194.9961 - val_root_mean_squared_error: 145.5850
# Epoch 33/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2363.2620 - root_mean_squared_error: 48.6034 - val_loss: 23569.4961 - val_root_mean_squared_error: 153.5236
# Epoch 34/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2067.1060 - root_mean_squared_error: 45.4324 - val_loss: 21643.1641 - val_root_mean_squared_error: 147.1162
# Epoch 35/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2478.4175 - root_mean_squared_error: 49.7550 - val_loss: 20349.6621 - val_root_mean_squared_error: 142.6522
# Epoch 36/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2309.4497 - root_mean_squared_error: 48.0131 - val_loss: 24308.0430 - val_root_mean_squared_error: 155.9104
# Epoch 37/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2212.3262 - root_mean_squared_error: 46.9818 - val_loss: 22350.5938 - val_root_mean_squared_error: 149.5011
# Epoch 38/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2257.2354 - root_mean_squared_error: 47.4652 - val_loss: 25398.5508 - val_root_mean_squared_error: 159.3692
# Epoch 39/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2400.3596 - root_mean_squared_error: 48.9768 - val_loss: 21528.8262 - val_root_mean_squared_error: 146.7271
# Epoch 40/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2183.7046 - root_mean_squared_error: 46.6778 - val_loss: 20860.5918 - val_root_mean_squared_error: 144.4320
# Epoch 41/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2160.2021 - root_mean_squared_error: 46.3436 - val_loss: 24263.8633 - val_root_mean_squared_error: 155.7686
# Epoch 42/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2190.0618 - root_mean_squared_error: 46.7342 - val_loss: 20284.1680 - val_root_mean_squared_error: 142.4225
# Epoch 43/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2134.2605 - root_mean_squared_error: 46.1443 - val_loss: 21025.6875 - val_root_mean_squared_error: 145.0024
# Epoch 44/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2643.0759 - root_mean_squared_error: 51.0934 - val_loss: 21309.3574 - val_root_mean_squared_error: 145.9772
# Epoch 45/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2265.1396 - root_mean_squared_error: 47.5179 - val_loss: 21207.3594 - val_root_mean_squared_error: 145.6275
# Epoch 46/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2339.7727 - root_mean_squared_error: 48.3552 - val_loss: 22839.4531 - val_root_mean_squared_error: 151.1273
# Epoch 47/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2348.4863 - root_mean_squared_error: 48.4296 - val_loss: 19854.0371 - val_root_mean_squared_error: 140.9044
# Epoch 48/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2669.8391 - root_mean_squared_error: 51.4533 - val_loss: 22412.7500 - val_root_mean_squared_error: 149.7089
# Epoch 49/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2389.1233 - root_mean_squared_error: 48.7585 - val_loss: 22164.2148 - val_root_mean_squared_error: 148.8765
# Epoch 50/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2295.2014 - root_mean_squared_error: 47.8410 - val_loss: 24747.2852 - val_root_mean_squared_error: 157.3127
# Epoch 51/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2317.8279 - root_mean_squared_error: 48.0797 - val_loss: 21381.6875 - val_root_mean_squared_error: 146.2248
# Epoch 52/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2405.2891 - root_mean_squared_error: 48.8826 - val_loss: 21098.8672 - val_root_mean_squared_error: 145.2545
# Epoch 53/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2238.5657 - root_mean_squared_error: 47.2675 - val_loss: 22749.4531 - val_root_mean_squared_error: 150.8292
# Epoch 54/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2239.4736 - root_mean_squared_error: 47.2341 - val_loss: 20598.2578 - val_root_mean_squared_error: 143.5209
# Epoch 55/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2278.6504 - root_mean_squared_error: 47.7103 - val_loss: 21855.0430 - val_root_mean_squared_error: 147.8345
# Epoch 56/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2294.5132 - root_mean_squared_error: 47.8667 - val_loss: 22072.4102 - val_root_mean_squared_error: 148.5679
# Epoch 57/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2476.6553 - root_mean_squared_error: 49.5542 - val_loss: 21480.6562 - val_root_mean_squared_error: 146.5628
# Epoch 58/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2518.7075 - root_mean_squared_error: 50.1435 - val_loss: 20394.1445 - val_root_mean_squared_error: 142.8081
# Epoch 59/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2458.4966 - root_mean_squared_error: 49.3350 - val_loss: 22079.5078 - val_root_mean_squared_error: 148.5918
# Epoch 60/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2247.0500 - root_mean_squared_error: 47.3904 - val_loss: 20808.0977 - val_root_mean_squared_error: 144.2501
# Epoch 61/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2188.6177 - root_mean_squared_error: 46.7314 - val_loss: 20583.1621 - val_root_mean_squared_error: 143.4683
# Epoch 62/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2104.7283 - root_mean_squared_error: 45.8336 - val_loss: 21016.4414 - val_root_mean_squared_error: 144.9705
# Epoch 63/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2105.9583 - root_mean_squared_error: 45.7776 - val_loss: 23638.9902 - val_root_mean_squared_error: 153.7498
# Epoch 64/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2355.1414 - root_mean_squared_error: 48.4504 - val_loss: 20840.4883 - val_root_mean_squared_error: 144.3624
# Epoch 65/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2391.3494 - root_mean_squared_error: 48.8119 - val_loss: 21150.8398 - val_root_mean_squared_error: 145.4333
# Epoch 66/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2249.3203 - root_mean_squared_error: 47.3994 - val_loss: 20690.9062 - val_root_mean_squared_error: 143.8433
# Epoch 67/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2172.8967 - root_mean_squared_error: 46.6013 - val_loss: 21137.5781 - val_root_mean_squared_error: 145.3877
# Epoch 68/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2104.1841 - root_mean_squared_error: 45.8082 - val_loss: 19652.4902 - val_root_mean_squared_error: 140.1873
# Epoch 69/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2057.4004 - root_mean_squared_error: 45.2982 - val_loss: 21231.8945 - val_root_mean_squared_error: 145.7117
# Epoch 70/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2102.6838 - root_mean_squared_error: 45.8090 - val_loss: 21197.0781 - val_root_mean_squared_error: 145.5922
# Epoch 71/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2352.5051 - root_mean_squared_error: 48.3592 - val_loss: 23422.8691 - val_root_mean_squared_error: 153.0453
# Epoch 72/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2508.6609 - root_mean_squared_error: 50.0255 - val_loss: 23603.4883 - val_root_mean_squared_error: 153.6343
# Epoch 73/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2547.8057 - root_mean_squared_error: 50.3569 - val_loss: 22264.5625 - val_root_mean_squared_error: 149.2132
# Epoch 74/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2534.3501 - root_mean_squared_error: 50.3045 - val_loss: 24682.5039 - val_root_mean_squared_error: 157.1067
# Epoch 75/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2229.3557 - root_mean_squared_error: 47.1867 - val_loss: 21357.9609 - val_root_mean_squared_error: 146.1436
# Epoch 76/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2030.6772 - root_mean_squared_error: 45.0157 - val_loss: 22777.8652 - val_root_mean_squared_error: 150.9234
# Epoch 77/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2253.0098 - root_mean_squared_error: 47.4573 - val_loss: 20038.9844 - val_root_mean_squared_error: 141.5591
# Epoch 78/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2469.9758 - root_mean_squared_error: 49.6234 - val_loss: 22023.1875 - val_root_mean_squared_error: 148.4021
# Epoch 79/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1983.9308 - root_mean_squared_error: 44.4792 - val_loss: 21430.6035 - val_root_mean_squared_error: 146.3920
# Epoch 80/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2423.2466 - root_mean_squared_error: 49.1330 - val_loss: 22007.5312 - val_root_mean_squared_error: 148.3494
# Epoch 81/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2092.4739 - root_mean_squared_error: 45.7094 - val_loss: 19984.1523 - val_root_mean_squared_error: 141.3653
# Epoch 82/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2262.8005 - root_mean_squared_error: 47.5425 - val_loss: 22442.3086 - val_root_mean_squared_error: 149.8076
# Epoch 83/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2153.3064 - root_mean_squared_error: 46.3552 - val_loss: 18719.1992 - val_root_mean_squared_error: 136.8181
# Epoch 84/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2302.3972 - root_mean_squared_error: 47.9462 - val_loss: 21053.7012 - val_root_mean_squared_error: 145.0989
# Epoch 85/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2182.0776 - root_mean_squared_error: 46.5943 - val_loss: 19166.0410 - val_root_mean_squared_error: 138.4415
# Epoch 86/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2407.0984 - root_mean_squared_error: 49.0381 - val_loss: 19950.1582 - val_root_mean_squared_error: 141.2450
# Epoch 87/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2552.7456 - root_mean_squared_error: 50.4887 - val_loss: 21883.1133 - val_root_mean_squared_error: 147.9294
# Epoch 88/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2696.1147 - root_mean_squared_error: 51.4134 - val_loss: 19574.1621 - val_root_mean_squared_error: 139.9077
# Epoch 89/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2017.5681 - root_mean_squared_error: 44.8778 - val_loss: 20036.6367 - val_root_mean_squared_error: 141.5508
# Epoch 90/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2107.5979 - root_mean_squared_error: 45.8607 - val_loss: 21113.3965 - val_root_mean_squared_error: 145.3045
# Epoch 91/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1991.9683 - root_mean_squared_error: 44.5317 - val_loss: 25622.3809 - val_root_mean_squared_error: 160.0699
# Epoch 92/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2456.4136 - root_mean_squared_error: 49.4484 - val_loss: 22333.3164 - val_root_mean_squared_error: 149.4434
# Epoch 93/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2418.2163 - root_mean_squared_error: 49.1146 - val_loss: 20686.6191 - val_root_mean_squared_error: 143.8284
# Epoch 94/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2135.3140 - root_mean_squared_error: 46.1822 - val_loss: 19443.6953 - val_root_mean_squared_error: 139.4407
# Epoch 95/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2279.6438 - root_mean_squared_error: 47.7145 - val_loss: 20372.6465 - val_root_mean_squared_error: 142.7328
# Epoch 96/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2267.1279 - root_mean_squared_error: 47.5658 - val_loss: 20955.1797 - val_root_mean_squared_error: 144.7590
# Epoch 97/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2272.6609 - root_mean_squared_error: 47.6071 - val_loss: 21548.0977 - val_root_mean_squared_error: 146.7927
# Epoch 98/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2443.8853 - root_mean_squared_error: 49.2537 - val_loss: 23079.3711 - val_root_mean_squared_error: 151.9190
# Epoch 99/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2224.8298 - root_mean_squared_error: 47.1083 - val_loss: 22088.7793 - val_root_mean_squared_error: 148.6229
# Epoch 100/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2203.7014 - root_mean_squared_error: 46.9289 - val_loss: 21210.9277 - val_root_mean_squared_error: 145.6397
# Epoch 101/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2131.8538 - root_mean_squared_error: 46.1281 - val_loss: 23961.2227 - val_root_mean_squared_error: 154.7941
# Epoch 102/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2019.2443 - root_mean_squared_error: 44.8900 - val_loss: 24397.8867 - val_root_mean_squared_error: 156.1982
# Epoch 103/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2153.4988 - root_mean_squared_error: 46.3537 - val_loss: 22276.5996 - val_root_mean_squared_error: 149.2535
# Epoch 104/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2242.7161 - root_mean_squared_error: 47.3206 - val_loss: 23610.3906 - val_root_mean_squared_error: 153.6567
# Epoch 105/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2286.4397 - root_mean_squared_error: 47.7682 - val_loss: 21751.6445 - val_root_mean_squared_error: 147.4844
# Epoch 106/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2193.1562 - root_mean_squared_error: 46.7609 - val_loss: 20350.0703 - val_root_mean_squared_error: 142.6537
# Epoch 107/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2235.4658 - root_mean_squared_error: 47.2057 - val_loss: 20776.9902 - val_root_mean_squared_error: 144.1423
# Epoch 108/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2231.0234 - root_mean_squared_error: 47.2173 - val_loss: 22372.9121 - val_root_mean_squared_error: 149.5758
# Epoch 109/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2085.2192 - root_mean_squared_error: 45.5499 - val_loss: 20989.3828 - val_root_mean_squared_error: 144.8771
# Epoch 110/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2073.5137 - root_mean_squared_error: 45.5089 - val_loss: 20428.5820 - val_root_mean_squared_error: 142.9286
# Epoch 111/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2102.5134 - root_mean_squared_error: 45.8179 - val_loss: 19892.1699 - val_root_mean_squared_error: 141.0396
# Epoch 112/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2440.7617 - root_mean_squared_error: 49.3765 - val_loss: 20155.3711 - val_root_mean_squared_error: 141.9696
# Epoch 113/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2124.5488 - root_mean_squared_error: 46.0138 - val_loss: 19607.7207 - val_root_mean_squared_error: 140.0276
# Epoch 114/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2330.7598 - root_mean_squared_error: 48.1987 - val_loss: 21389.5742 - val_root_mean_squared_error: 146.2518
# Epoch 115/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2217.2061 - root_mean_squared_error: 47.0352 - val_loss: 23154.4355 - val_root_mean_squared_error: 152.1658
# Epoch 116/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2135.8494 - root_mean_squared_error: 46.1367 - val_loss: 23678.3125 - val_root_mean_squared_error: 153.8776
# Epoch 117/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2150.2317 - root_mean_squared_error: 46.3077 - val_loss: 22602.5352 - val_root_mean_squared_error: 150.3414
# Epoch 118/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2818.0771 - root_mean_squared_error: 52.7917 - val_loss: 21940.5039 - val_root_mean_squared_error: 148.1233
# Epoch 119/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2253.9368 - root_mean_squared_error: 47.3843 - val_loss: 20306.3633 - val_root_mean_squared_error: 142.5004
# Epoch 120/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2194.5972 - root_mean_squared_error: 46.7769 - val_loss: 20889.9512 - val_root_mean_squared_error: 144.5336
# Epoch 121/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2169.1648 - root_mean_squared_error: 46.4986 - val_loss: 23055.0566 - val_root_mean_squared_error: 151.8389
# Epoch 122/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2143.5637 - root_mean_squared_error: 46.2412 - val_loss: 21525.5117 - val_root_mean_squared_error: 146.7157
# Epoch 123/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2255.5872 - root_mean_squared_error: 47.4714 - val_loss: 22059.5293 - val_root_mean_squared_error: 148.5245
# Epoch 124/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2380.2700 - root_mean_squared_error: 48.7622 - val_loss: 21321.8086 - val_root_mean_squared_error: 146.0199
# Epoch 125/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2544.9248 - root_mean_squared_error: 50.3212 - val_loss: 21818.4668 - val_root_mean_squared_error: 147.7108
# Epoch 126/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2245.6238 - root_mean_squared_error: 47.3594 - val_loss: 19570.4766 - val_root_mean_squared_error: 139.8945
# Epoch 127/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2122.7134 - root_mean_squared_error: 46.0350 - val_loss: 20825.0918 - val_root_mean_squared_error: 144.3090
# Epoch 128/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2455.0137 - root_mean_squared_error: 49.4643 - val_loss: 21037.8477 - val_root_mean_squared_error: 145.0443
# Epoch 129/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1998.8312 - root_mean_squared_error: 44.6880 - val_loss: 18976.1445 - val_root_mean_squared_error: 137.7539
# Epoch 130/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2179.5542 - root_mean_squared_error: 46.6527 - val_loss: 20148.1875 - val_root_mean_squared_error: 141.9443
# Epoch 131/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2059.9470 - root_mean_squared_error: 45.3135 - val_loss: 19518.7773 - val_root_mean_squared_error: 139.7096
# Epoch 132/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2215.9172 - root_mean_squared_error: 46.9893 - val_loss: 21023.9727 - val_root_mean_squared_error: 144.9965
# Epoch 133/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2511.3271 - root_mean_squared_error: 50.0473 - val_loss: 18190.4258 - val_root_mean_squared_error: 134.8719
# Epoch 134/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2004.8313 - root_mean_squared_error: 44.7311 - val_loss: 18061.6094 - val_root_mean_squared_error: 134.3935
# Epoch 135/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2286.2383 - root_mean_squared_error: 47.7852 - val_loss: 17430.4023 - val_root_mean_squared_error: 132.0242
# Epoch 136/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1966.2697 - root_mean_squared_error: 44.2965 - val_loss: 17550.7910 - val_root_mean_squared_error: 132.4794
# Epoch 137/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2148.7854 - root_mean_squared_error: 46.3299 - val_loss: 18306.5020 - val_root_mean_squared_error: 135.3015
# Epoch 138/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1996.9823 - root_mean_squared_error: 44.6495 - val_loss: 19036.1055 - val_root_mean_squared_error: 137.9714
# Epoch 139/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2059.7446 - root_mean_squared_error: 45.3349 - val_loss: 17443.2656 - val_root_mean_squared_error: 132.0730
# Epoch 140/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2414.1450 - root_mean_squared_error: 49.0837 - val_loss: 19142.7734 - val_root_mean_squared_error: 138.3574
# Epoch 141/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2222.7322 - root_mean_squared_error: 47.1142 - val_loss: 17516.2363 - val_root_mean_squared_error: 132.3489
# Epoch 142/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2397.3813 - root_mean_squared_error: 48.8139 - val_loss: 16997.5566 - val_root_mean_squared_error: 130.3747
# Epoch 143/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2156.5645 - root_mean_squared_error: 46.3548 - val_loss: 18319.4102 - val_root_mean_squared_error: 135.3492
# Epoch 144/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2024.3923 - root_mean_squared_error: 44.9707 - val_loss: 18290.6523 - val_root_mean_squared_error: 135.2429
# Epoch 145/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2066.1436 - root_mean_squared_error: 45.3113 - val_loss: 18791.1621 - val_root_mean_squared_error: 137.0809
# Epoch 146/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2199.7314 - root_mean_squared_error: 46.8556 - val_loss: 18501.0078 - val_root_mean_squared_error: 136.0184
# Epoch 147/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2060.1504 - root_mean_squared_error: 45.3028 - val_loss: 20901.6562 - val_root_mean_squared_error: 144.5741
# Epoch 148/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2032.7909 - root_mean_squared_error: 45.0473 - val_loss: 18302.8535 - val_root_mean_squared_error: 135.2880
# Epoch 149/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2140.4119 - root_mean_squared_error: 46.2069 - val_loss: 16922.2773 - val_root_mean_squared_error: 130.0856
# Epoch 150/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2153.3689 - root_mean_squared_error: 46.3700 - val_loss: 17333.0020 - val_root_mean_squared_error: 131.6549
# Epoch 151/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2540.2500 - root_mean_squared_error: 50.3523 - val_loss: 16168.2109 - val_root_mean_squared_error: 127.1543
# Epoch 152/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2169.8687 - root_mean_squared_error: 46.5159 - val_loss: 16155.5264 - val_root_mean_squared_error: 127.1044
# Epoch 153/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2124.5906 - root_mean_squared_error: 46.0813 - val_loss: 14362.3027 - val_root_mean_squared_error: 119.8428
# Epoch 154/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2202.0566 - root_mean_squared_error: 46.9041 - val_loss: 14010.2090 - val_root_mean_squared_error: 118.3647
# Epoch 155/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2111.9812 - root_mean_squared_error: 45.8666 - val_loss: 14213.5332 - val_root_mean_squared_error: 119.2205
# Epoch 156/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2399.3821 - root_mean_squared_error: 48.8864 - val_loss: 14655.5723 - val_root_mean_squared_error: 121.0602
# Epoch 157/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1991.0529 - root_mean_squared_error: 44.5989 - val_loss: 13827.2920 - val_root_mean_squared_error: 117.5895
# Epoch 158/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2155.6873 - root_mean_squared_error: 46.2863 - val_loss: 13371.0059 - val_root_mean_squared_error: 115.6331
# Epoch 159/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2221.6628 - root_mean_squared_error: 47.1160 - val_loss: 12618.9268 - val_root_mean_squared_error: 112.3340
# Epoch 160/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2209.2512 - root_mean_squared_error: 46.9881 - val_loss: 12848.0830 - val_root_mean_squared_error: 113.3494
# Epoch 161/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2600.6611 - root_mean_squared_error: 50.9543 - val_loss: 14694.5801 - val_root_mean_squared_error: 121.2212
# Epoch 162/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1847.9286 - root_mean_squared_error: 42.9127 - val_loss: 15371.2324 - val_root_mean_squared_error: 123.9808
# Epoch 163/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2232.7310 - root_mean_squared_error: 47.2037 - val_loss: 16262.0957 - val_root_mean_squared_error: 127.5229
# Epoch 164/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2167.8333 - root_mean_squared_error: 46.4753 - val_loss: 16632.6055 - val_root_mean_squared_error: 128.9675
# Epoch 165/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2086.4575 - root_mean_squared_error: 45.6115 - val_loss: 15392.5605 - val_root_mean_squared_error: 124.0668
# Epoch 166/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2628.1008 - root_mean_squared_error: 51.2057 - val_loss: 15803.0859 - val_root_mean_squared_error: 125.7103
# Epoch 167/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2219.9431 - root_mean_squared_error: 47.1015 - val_loss: 16228.8379 - val_root_mean_squared_error: 127.3925
# Epoch 168/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2114.7168 - root_mean_squared_error: 45.9518 - val_loss: 15165.5918 - val_root_mean_squared_error: 123.1487
# Epoch 169/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2073.2754 - root_mean_squared_error: 45.5106 - val_loss: 15087.9512 - val_root_mean_squared_error: 122.8330
# Epoch 170/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2240.5144 - root_mean_squared_error: 47.2723 - val_loss: 14555.1074 - val_root_mean_squared_error: 120.6445
# Epoch 171/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2131.9641 - root_mean_squared_error: 46.0736 - val_loss: 12889.4326 - val_root_mean_squared_error: 113.5316
# Epoch 172/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2219.6470 - root_mean_squared_error: 47.0218 - val_loss: 13058.2500 - val_root_mean_squared_error: 114.2727
# Epoch 173/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2214.9026 - root_mean_squared_error: 46.9750 - val_loss: 13270.5098 - val_root_mean_squared_error: 115.1977
# Epoch 174/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2299.0786 - root_mean_squared_error: 47.9275 - val_loss: 12456.3760 - val_root_mean_squared_error: 111.6081
# Epoch 175/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2158.8413 - root_mean_squared_error: 46.4425 - val_loss: 14159.8184 - val_root_mean_squared_error: 118.9950
# Epoch 176/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1926.2120 - root_mean_squared_error: 43.8517 - val_loss: 13877.0859 - val_root_mean_squared_error: 117.8011
# Epoch 177/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2574.0032 - root_mean_squared_error: 50.4945 - val_loss: 14185.9014 - val_root_mean_squared_error: 119.1046
# Epoch 178/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2311.5708 - root_mean_squared_error: 48.0309 - val_loss: 13761.5830 - val_root_mean_squared_error: 117.3098
# Epoch 179/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2588.9417 - root_mean_squared_error: 50.5909 - val_loss: 13028.2881 - val_root_mean_squared_error: 114.1415
# Epoch 180/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2415.0403 - root_mean_squared_error: 48.8466 - val_loss: 13655.5996 - val_root_mean_squared_error: 116.8572
# Epoch 181/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2034.8508 - root_mean_squared_error: 45.0844 - val_loss: 12814.0801 - val_root_mean_squared_error: 113.1993
# Epoch 182/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2197.9258 - root_mean_squared_error: 46.8367 - val_loss: 12976.2705 - val_root_mean_squared_error: 113.9134
# Epoch 183/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2153.6187 - root_mean_squared_error: 46.3761 - val_loss: 13541.7559 - val_root_mean_squared_error: 116.3690
# Epoch 184/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2247.8164 - root_mean_squared_error: 47.3985 - val_loss: 14623.7090 - val_root_mean_squared_error: 120.9285
# Epoch 185/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2134.9551 - root_mean_squared_error: 46.1864 - val_loss: 13284.9941 - val_root_mean_squared_error: 115.2606
# Epoch 186/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2239.6052 - root_mean_squared_error: 47.2458 - val_loss: 11714.9248 - val_root_mean_squared_error: 108.2355
# Epoch 187/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1994.9500 - root_mean_squared_error: 44.6361 - val_loss: 11775.1113 - val_root_mean_squared_error: 108.5132
# Epoch 188/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2027.0729 - root_mean_squared_error: 45.0118 - val_loss: 12594.8604 - val_root_mean_squared_error: 112.2268
# Epoch 189/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2216.6697 - root_mean_squared_error: 47.0519 - val_loss: 12991.9043 - val_root_mean_squared_error: 113.9820
# Epoch 190/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2069.4468 - root_mean_squared_error: 45.4374 - val_loss: 11518.5723 - val_root_mean_squared_error: 107.3246
# Epoch 191/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1980.5383 - root_mean_squared_error: 44.4629 - val_loss: 11623.1436 - val_root_mean_squared_error: 107.8107
# Epoch 192/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1992.5580 - root_mean_squared_error: 44.6017 - val_loss: 10927.5479 - val_root_mean_squared_error: 104.5349
# Epoch 193/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2208.8196 - root_mean_squared_error: 46.8768 - val_loss: 12197.9238 - val_root_mean_squared_error: 110.4442
# Epoch 194/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2182.7053 - root_mean_squared_error: 46.6610 - val_loss: 11797.9678 - val_root_mean_squared_error: 108.6185
# Epoch 195/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2066.0820 - root_mean_squared_error: 45.4211 - val_loss: 12254.4053 - val_root_mean_squared_error: 110.6996
# Epoch 196/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1828.0132 - root_mean_squared_error: 42.5760 - val_loss: 11100.2031 - val_root_mean_squared_error: 105.3575
# Epoch 197/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2133.8103 - root_mean_squared_error: 46.1631 - val_loss: 11586.0488 - val_root_mean_squared_error: 107.6385
# Epoch 198/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1968.0698 - root_mean_squared_error: 44.3445 - val_loss: 10908.0449 - val_root_mean_squared_error: 104.4416
# Epoch 199/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2280.5671 - root_mean_squared_error: 47.6504 - val_loss: 12199.8096 - val_root_mean_squared_error: 110.4528
# Epoch 200/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2318.0867 - root_mean_squared_error: 48.0269 - val_loss: 12371.0840 - val_root_mean_squared_error: 111.2254
# TF 2.19.0
# X_train (1000, 15) y_train (1000,)
# X_val (320, 15) y_val (320,)
# pred[:5] [1728.659  1647.9143 1681.9811 1668.8809 1685.6085]
# test_rmse 45.84516906738281
# saved: artifacts/bof_temp_model.keras artifacts/feature_schema.json artifacts/pred.csv
